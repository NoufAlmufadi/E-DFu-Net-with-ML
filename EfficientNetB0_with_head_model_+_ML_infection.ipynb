# %%
import tensorflow.keras
import numpy as np
import matplotlib.pyplot as plt
import glob
import cv2
from keras import optimizers
from keras.layers import Input, Lambda, Dense, Flatten, Dropout
from keras.models import Model
from tensorflow.keras.applications import EfficientNetB0
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras import metrics
from glob import glob
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn import metrics
import os
from imutils import paths
from cv2 import imread
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.utils import shuffle
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
pip install -q -U keras-tuner
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 1.5 MB/s eta 0:00:00

# %%
pip install plot_keras_history
# Out:
# Collecting plot_keras_history
#   Downloading plot_keras_history-1.1.38.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from plot_keras_history) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from plot_keras_history) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from plot_keras_history) (1.11.4)
# Collecting support_developer>=1.0.2 (from plot_keras_history)
#   Downloading support_developer-1.0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sanitize_ml_labels>=1.0.48 (from plot_keras_history)
#   Downloading sanitize_ml_labels-1.0.51.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting compress_json (from sanitize_ml_labels>=1.0.48->plot_keras_history)
#   Downloading compress_json-1.0.10.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->plot_keras_history) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.16.0)
# Building wheels for collected packages: plot_keras_history, sanitize_ml_labels, support_developer, compress_json
#   Building wheel for plot_keras_history (setup.py) ... done
#   Created wheel for plot_keras_history: filename=plot_keras_history-1.1.38-py3-none-any.whl size=9455 sha256=773d6851691fd27e6163ac09a376ef32ea2a217c629a338ac91be7207bdf0a38
#   Stored in directory: /root/.cache/pip/wheels/2f/31/6c/bbc9703b7baa8bd3802a8aedd9e2f9e66941b0cf0d456ab4cc
#   Building wheel for sanitize_ml_labels (setup.py) ... done
#   Created wheel for sanitize_ml_labels: filename=sanitize_ml_labels-1.0.51-py3-none-any.whl size=321865 sha256=428facaf870dc86682cfacf366ac7326ce2d4a7e936db201d804e64b47cb20f3
#   Stored in directory: /root/.cache/pip/wheels/30/9f/f5/37d037c39ac8b305590d5956f7021c6ca94b63c68be24f6841
#   Building wheel for support_developer (setup.py) ... done
#   Created wheel for support_developer: filename=support_developer-1.0.5-py3-none-any.whl size=5630 sha256=54f7686ed73bd582637fddcbdb25ec4ca3767060d9196a9d0349e7050d4f24c0
#   Stored in directory: /root/.cache/pip/wheels/b6/72/c8/3054a5897ba0713dfa7a941364d68cbd42b0755c8e2ec1c18c
#   Building wheel for compress_json (setup.py) ... done
#   Created wheel for compress_json: filename=compress_json-1.0.10-py3-none-any.whl size=5817 sha256=94aacc1486fa509fd12c3cccd4a17acb46ea0bc6819493fa21378827973305e3
#   Stored in directory: /root/.cache/pip/wheels/7b/55/94/bc79987b855aac5990e0d015c2e604aa50bc5147673e98530c
# Successfully built plot_keras_history sanitize_ml_labels support_developer compress_json
# Installing collected packages: support_developer, compress_json, sanitize_ml_labels, plot_keras_history
# Successfully installed compress_json-1.0.10 plot_keras_history-1.1.38 sanitize_ml_labels-1.0.51 support_developer-1.0.5

# %%
from plot_keras_history import show_history, plot_history

# %%
IMAGE_SIZE = [224, 224]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import tensorflow as tf
from sklearn import preprocessing



train_images = []
train_labels = []

test_images = []
test_labels = []

val_images = []

for directory_path in glob.glob("/content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/train/*"):
    label = os.path.split(directory_path)
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        print(img_path)
        image=tf.keras.preprocessing.image.load_img(img_path, color_mode='rgb',
        target_size= (224,224))
        image=np.array(image)
        train_images.append(image)
        train_labels.append(label)

for directory_path1 in glob.glob("/content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split
jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_203_709374.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_712_7085613.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_323_316317.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_340_9115129.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_359_7558271.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_53_6249511.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_721_3029138.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_706_2987075.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_609_9360605.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_702_2177429.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_427_7963654.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_287_8788746.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_1_3755766.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_590_2978561.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_400_6676402.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_28_9652915.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_735_1030789.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_205_2879689.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_252_8598679.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_784_6568988.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_773_8303030.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_580_4770734.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_583_9413248.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_202_4388628.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_371_4014253.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_446_6732470.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_405_2557348.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_329_6938179.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_730_1074949.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_221_2180030.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_120_4147820.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_489_5513842.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_156_5428495.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_458_3935472.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_790_4313980.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_631_1181104.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_715_2823904.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_383_8592626.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_37_1088974.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_116_9634310.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_558_6020327.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_766_3925651.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_328_9037010.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_588_6770639.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_686_2865700.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_325_8108451.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_74_3401312.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_250_6511241.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_73_5445517.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_579_7725020.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_198_6396373.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_647_607173.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_314_4462469.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_474_26410.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_354_3080426.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_311_5646096.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_476_5478764.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_582_7880550.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_525_4704430.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_763_2322351.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_282_8577782.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_612_4018259.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_496_1701551.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_598_9317547.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_737_852690.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_707_7807607.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_173_9466511.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_589_4972566.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_220_5425792.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_390_1151960.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_700_4711472.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_529_4320993.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_493_1611307.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_137_6659019.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_351_7864918.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_477_265389.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_33_9035350.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_57_3885524.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_731_7992926.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_317_1621424.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_109_422560.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_235_1313869.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_217_9954172.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_61_5516784.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_389_7468862.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_541_1945552.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_435_7915854.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_273_127141.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_84_2379366.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_553_7004206.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_297_466700.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_63_2658271.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_458_1165818.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_624_17351.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_19_5258897.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_79_6478179.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_197_6256910.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_749_8797727.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_212_3050853.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_224_8779870.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_111_3604450.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_532_4809330.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_100_3427365.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_123_6871660.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_768_5486557.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_681_7961886.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_783_999144.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_190_5938707.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_239_2375934.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_379_1055605.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_395_8297126.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_216_5896535.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_3_1562391.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_282_5018919.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_289_9198226.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_204_257744.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_169_748655.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_454_1558375.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_574_6482279.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_175_5380733.jpg
# /content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val/Aug-Positive/_722_3287114.jpg
# (844, 2)
# (5896, 2)
# (5896, 224, 224, 3)
# (844, 224, 224, 3)
# (1684, 224, 224, 3)

# %%
from tensorflow.keras.applications import EfficientNetB0

EfficientNetB0 = EfficientNetB0(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
EfficientNetB0.input
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_1')>

# %%
for layer in EfficientNetB0.layers:
  layer.trainable = False

# %%
from tensorflow.keras.layers import BatchNormalization

x = Flatten()(EfficientNetB0.output)
x = tf.keras.layers.Dropout(0.5)(x)
x=BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001)(x)
x = tf.keras.layers.Dropout(0.5)(x)
x=BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001)(x)
x=Dense(256, kernel_regularizer= tensorflow.keras.regularizers.l2(l= 0.016), activity_regularizer= tensorflow.keras.regularizers.l1(0.006),bias_regularizer= tensorflow.keras.regularizers.l1(0.006), activation= 'relu')(x)
x = tf.keras.layers.Dropout(0.5)(x)
x=Dense(128, kernel_regularizer= tensorflow.keras.regularizers.l2(l= 0.016), activity_regularizer= tensorflow.keras.regularizers.l1(0.006),bias_regularizer= tensorflow.keras.regularizers.l1(0.006), activation= 'relu')(x)
x=Dropout(rate= 0.45, seed= 123)(x)
prediction = Dense(2,activation='sigmoid')(x)
model = Model(inputs=EfficientNetB0.input, outputs=prediction)

# %%
train_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()
val_datagen = ImageDataGenerator()

# %%
train_set = train_datagen.flow_from_directory('/content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 5896 images belonging to 2 classes.

# %%
# Create a generator for the test data without augmentation
test_set = test_datagen.flow_from_directory('/content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/test',
                                                  target_size=(224, 224),
                                                  batch_size=32,
                                                  class_mode='categorical' )
# Out:
# Found 844 images belonging to 2 classes.

# %%
val_set = val_datagen.flow_from_directory('/content/drive/My Drive/datasets/infec_agu_code_bycolab_8000split/val',
                                                  target_size=(224, 224),
                                                  batch_size=32,
                                                  class_mode='categorical' )
# Out:
# Found 1684 images belonging to 2 classes.

# %%
from keras.optimizers import Adamax
model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss',verbose=1, patience=20)

# %%
import time

#starting time
start = time.time()

batch_size = 32
#batch_size = 64
#batch_size = 128
hist = model.fit(train_set, steps_per_epoch = train_set.samples//batch_size,
                 validation_data = val_set,validation_steps = val_set.samples//batch_size,
                 epochs = 100,callbacks=[es]
                 )
# end time
end = time.time()

# total time taken
print("Execution time of the program is- ", end-start)
# Out:
# Epoch 1/100
# 184/184 [==============================] - 38s 125ms/step - loss: 13.9387 - accuracy: 0.6482 - val_loss: 11.9594 - val_accuracy: 0.7873
# Epoch 2/100
# 184/184 [==============================] - 22s 122ms/step - loss: 10.8584 - accuracy: 0.7357 - val_loss: 9.2705 - val_accuracy: 0.8173
# Epoch 3/100
# 184/184 [==============================] - 23s 126ms/step - loss: 8.2351 - accuracy: 0.7822 - val_loss: 7.0394 - val_accuracy: 0.8389
# Epoch 4/100
# 184/184 [==============================] - 27s 148ms/step - loss: 6.1664 - accuracy: 0.8082 - val_loss: 5.2508 - val_accuracy: 0.8413
# Epoch 5/100
# 184/184 [==============================] - 23s 124ms/step - loss: 4.5670 - accuracy: 0.8303 - val_loss: 3.8758 - val_accuracy: 0.8582
# Epoch 6/100
# 184/184 [==============================] - 21s 116ms/step - loss: 3.3909 - accuracy: 0.8458 - val_loss: 2.9044 - val_accuracy: 0.8594
# Epoch 7/100
# 184/184 [==============================] - 23s 123ms/step - loss: 2.5887 - accuracy: 0.8566 - val_loss: 2.2748 - val_accuracy: 0.8768
# Epoch 8/100
# 184/184 [==============================] - 22s 119ms/step - loss: 2.0804 - accuracy: 0.8656 - val_loss: 1.8855 - val_accuracy: 0.8822
# Epoch 9/100
# 184/184 [==============================] - 22s 121ms/step - loss: 1.7711 - accuracy: 0.8724 - val_loss: 1.6416 - val_accuracy: 0.8804
# Epoch 10/100
# 184/184 [==============================] - 21s 114ms/step - loss: 1.5762 - accuracy: 0.8823 - val_loss: 1.5045 - val_accuracy: 0.8948
# Epoch 11/100
# 184/184 [==============================] - 22s 120ms/step - loss: 1.4637 - accuracy: 0.8924 - val_loss: 1.4162 - val_accuracy: 0.8984
# Epoch 12/100
# 184/184 [==============================] - 22s 118ms/step - loss: 1.3759 - accuracy: 0.9028 - val_loss: 1.3549 - val_accuracy: 0.8984
# Epoch 13/100
# 184/184 [==============================] - 29s 159ms/step - loss: 1.3379 - accuracy: 0.9055 - val_loss: 1.3256 - val_accuracy: 0.9147
# Epoch 14/100
# 184/184 [==============================] - 22s 119ms/step - loss: 1.
100
# 184/184 [==============================] - 22s 119ms/step - loss: 1.3182 - accuracy: 0.9212 - val_loss: 1.3072 - val_accuracy: 0.9261
# Epoch 51/100
# 184/184 [==============================] - 24s 130ms/step - loss: 1.3114 - accuracy: 0.9306 - val_loss: 1.3128 - val_accuracy: 0.9183
# Epoch 52/100
# 184/184 [==============================] - 21s 115ms/step - loss: 1.3205 - accuracy: 0.9233 - val_loss: 1.3234 - val_accuracy: 0.9213
# Epoch 53/100
# 184/184 [==============================] - 23s 125ms/step - loss: 1.3226 - accuracy: 0.9222 - val_loss: 1.3192 - val_accuracy: 0.9207
# Epoch 54/100
# 184/184 [==============================] - 23s 125ms/step - loss: 1.3240 - accuracy: 0.9238 - val_loss: 1.3311 - val_accuracy: 0.9129
# Epoch 55/100
# 184/184 [==============================] - 23s 127ms/step - loss: 1.3371 - accuracy: 0.9173 - val_loss: 1.3314 - val_accuracy: 0.9141
# Epoch 56/100
# 184/184 [==============================] - 22s 118ms/step - loss: 1.3271 - accuracy: 0.9207 - val_loss: 1.3386 - val_accuracy: 0.9075
# Epoch 57/100
# 184/184 [==============================] - 22s 119ms/step - loss: 1.3031 - accuracy: 0.9287 - val_loss: 1.3092 - val_accuracy: 0.9231
# Epoch 58/100
# 184/184 [==============================] - 22s 120ms/step - loss: 1.3195 - accuracy: 0.9205 - val_loss: 1.3314 - val_accuracy: 0.9165
# Epoch 59/100
# 184/184 [==============================] - 23s 125ms/step - loss: 1.3192 - accuracy: 0.9275 - val_loss: 1.3281 - val_accuracy: 0.9147
# Epoch 60/100
# 184/184 [==============================] - 22s 122ms/step - loss: 1.3306 - accuracy: 0.9250 - val_loss: 1.3215 - val_accuracy: 0.9291
# Epoch 61/100
# 184/184 [==============================] - 23s 123ms/step - loss: 1.3177 - accuracy: 0.9258 - val_loss: 1.3389 - val_accuracy: 0.9159
# Epoch 61: early stopping
# Execution time of the program is-  1937.1453654766083

# %%
# plot the loss
plt.plot(hist.history['loss'], label='train loss',marker='o')
plt.plot(hist.history['val_loss'], label='val loss',marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# plot the loss
plt.plot(hist.history['accuracy'], label='train accuracy',marker='o')
plt.plot(hist.history['val_accuracy'], label='val accuracy',marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
train_labels = train_labels[:, 1]
test_labels = test_labels[:, 1]

# %%
label_mapping = {'Aug-Negative': 0, 'Aug-Positive': 1}
train_labels = np.array([label_mapping[label] for label in train_labels])
test_labels = np.array([label_mapping[label] for label in test_labels])

# %%
from sklearn import metrics

# Make predictions on the training data
train_pred_probs = model.predict(train_images)  # Use the original training data
train_pred_labels = np.argmax(train_pred_probs, axis=1)

# Make predictions on the test data
test_pred_probs = model.predict(test_images)
test_pred_labels = np.argmax(test_pred_probs, axis=1)

# Ensure that train_labels and test_labels are correctly shaped
# They should be one-dimensional arrays if not already
train_labels = np.squeeze(train_labels)
test_labels = np.squeeze(test_labels)

# Calculate the accuracy scores
train_accuracy = metrics.accuracy_score(train_labels, train_pred_labels)
test_accuracy = metrics.accuracy_score(test_labels, test_pred_labels)

print("\nTraining Accuracy Score:", train_accuracy * 100)
print("\nTesting Accuracy Score:", test_accuracy * 100)
# Out:
# 185/185 [==============================] - 13s 61ms/step
# 27/27 [==============================] - 3s 96ms/step
#
# Training Accuracy Score: 99.25373134328358
#
# Testing Accuracy Score: 91.23222748815166

# %%
from sklearn.metrics import precision_score

from sklearn.metrics import recall_score

from sklearn.metrics import f1_score

from sklearn.metrics import cohen_kappa_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score





# accuracy: (tp + tn) / (p + n)

accuracy = accuracy_score(test_labels, test_pred_labels)

print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(test_labels, test_pred_labels)

print('Precision: %f' %precision)

# recall: tp / (tp + fn)

recall = recall_score(test_labels, test_pred_labels)

print('Recall: %f' % recall)


Specificity = recall_score(test_labels, test_pred_labels, pos_label= 0)

print('Specificity: %f' % Specificity)

# f1: 2 tp / (2 tp + fp + fn)

f1 = f1_score(test_labels, test_pred_labels)

print('F1 score: %f' % f1)

roc_auc = roc_auc_score(test_labels, test_pred_labels)

print('roc_auc: %f' % roc_auc)
# Out:
# Accuracy: 0.912322
# Precision: 0.941624
# Recall: 0.879147
# Specificity: 0.945498
# F1 score: 0.909314
# roc_auc: 0.912322

# %%
import numpy as np
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(test_labels, test_pred_labels)

# %%
roc_data = np.column_stack((fpr, tpr,thresholds))

# %%
import os
current_directory = os.getcwd()
print(current_directory)
# Out:
# /content

# %%
np.savetxt('/content/drive/My Drive/rocfiles/roc_curve_effb0_head_infec.dat', roc_data, delimiter='\t')

# %%
feat_train=model.predict(train_images)
feat_train=feat_train.reshape(feat_train.shape[0], -1)

feat_test=model.predict(test_images)
feat_test=feat_test.reshape(feat_test.shape[0], -1)
# Out:
# 185/185 [==============================] - 10s 55ms/step
# 27/27 [==============================] - 2s 66ms/step

# %%
labels = np.array(train_labels)
test_labels=np.array(test_labels)

# %%
# importing libraries
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LinearRegression

# %%
pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(feat_train,feat_test,labels,test_labels)

print(models)
# Out:
#  97%|█████████▋| 28/29 [00:08<00:00,  4.21it/s]
# [LightGBM] [Info] Number of positive: 2948, number of negative: 2948
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000313 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 5896, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:08<00:00,  3.34it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SGDClassifier                      0.93               0.93     0.93      0.93
# AdaBoostClassifier                 0.93               0.93     0.93      0.93
# Perceptron                         0.93               0.93     0.93      0.93
# SVC                                0.93               0.93     0.93      0.93
# LinearSVC                          0.93               0.93     0.93      0.93
# LGBMClassifier                     0.93               0.93     0.93      0.93
# LogisticRegression                 0.93               0.93     0.93      0.93
# LabelPropagation                   0.92               0.92     0.92      0.92
# CalibratedClassifierCV             0.92               0.92     0.92      0.92
# XGBClassifier                      0.92               0.92     0.92      0.92
# LabelSpreading                     0.92               0.92     0.92      0.92
# LinearDiscriminantAnalysis         0.92               0.92     0.92      0.92
# BaggingClassifier                  0.92               0.92     0.92      0.92
# RandomForestClassifier             0.92               0.92     0.92      0.92
# QuadraticDiscriminantAnalysis      0.92               0.92     0.92      0.92
# RidgeClassifierCV                  0.92               0.92     0.92      0.92
# ExtraTreesClassifier               0.92               0.92     0.92      0.92
# KNeighborsClassifier               0.92               0.92     0.92      0.92
# DecisionTreeClassifier             0.92               0.92     0.92      0.92
# ExtraTreeClassifier                0.91               0.91     0.91      0.91
# PassiveAggressiveClassifier        0.91               0.91     0.91      0.91
# GaussianNB                         0.91               0.91     0.91      0.91
# RidgeClassifier                    0.91               0.91     0.91      0.91
# NearestCentroid                    0.91               0.91     0.91      0.91
# BernoulliNB                        0.91               0.91     0.91      0.91
# NuSVC                              0.90               0.90     0.90      0.90
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# SGDClassifier                        0.05
# AdaBoostClassifier                   0.38
# Perceptron                           0.04
# SVC                                  0.09
# LinearSVC                            0.04
# LGBMClassifier                       0.27
# LogisticRegression                   0.08
# LabelPropagation                     1.18
# CalibratedClassifierCV               0.09
# XGBClassifier                        0.30
# LabelSpreading                       2.26
# LinearDiscriminantAnalysis           0.06
# BaggingClassifier                    0.12
# RandomForestClassifier               0.90
# QuadraticDiscriminantAnalysis        0.05
# RidgeClassifierCV                    0.07
# ExtraTreesClassifier                 0.27
# KNeighborsClassifier                 0.09
# DecisionTreeClassifier               0.03
# ExtraTreeClassifier                  0.02
# PassiveAggressiveClassifier          0.05
# GaussianNB                           0.02
# RidgeClassifier                      0.09
# NearestCentroid                      0.12
# BernoulliNB                          0.02
# NuSVC                                1.92
# DummyClassifier                      0.02

# %%
from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier(random_state=0)
#xgb = xgb(tol=1e-3, random_state=0)
ada.fit(feat_train, labels)

# Make predictions on the training and test data
predictedtrain = ada.predict(feat_train)
predictedtest = ada.predict(feat_test)

# Calculate and print the training and testing accuracy scores
train_accuracy = accuracy_score(labels, predictedtrain)
test_accuracy = accuracy_score(test_labels, predictedtest)

print("Training Accuracy Score:", train_accuracy* 100)
print("Testing Accuracy Score:", test_accuracy* 100)

accuracy = accuracy_score(test_labels, predictedtest)

print('Accuracy: %f' % accuracy)

# precision tp / (tp + fp)
precision = precision_score(test_labels, predictedtest)

print('Precision: %f' %precision)

# recall: tp / (tp + fn)

recall = recall_score(test_labels, predictedtest)

print('Recall: %f' % recall)


Specificity = recall_score(test_labels, predictedtest, pos_label= 0)

print('Specificity: %f' % Specificity)

# f1: 2 tp / (2 tp + fp + fn)

f1 = f1_score(test_labels, predictedtest)

print('F1 score: %f' % f1)

roc_auc = roc_auc_score(test_labels, predictedtest)

print('roc_auc: %f' % roc_auc)
# Out:
# Training Accuracy Score: 99.54206241519674
# Testing Accuracy Score: 92.77251184834124
# Accuracy: 0.927725
# Precision: 0.934940
# Recall: 0.919431
# Specificity: 0.936019
# F1 score: 0.927121
# roc_auc: 0.927725

# %%
# calculate roc curves

#ns_fpr, ns_tpr, _ = roc_curve(test_labels, predictedtest)

fpr, tpr, thresholds = roc_curve(test_labels, predictedtest)

# %%
roc_data = np.column_stack((fpr, tpr,thresholds))

# %%
np.savetxt('/content/drive/My Drive/rocfiles/roc_curve_effb0_headMl_infec.dat', roc_data, delimiter='\t')
